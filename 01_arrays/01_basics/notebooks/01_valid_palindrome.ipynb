# %% [markdown]
# ## Problem: Valid Palindrome
#
# A phrase is a palindrome if, after converting all uppercase letters to lowercase and removing all non-alphanumeric characters, it reads the same forwards and backwards.
#
# Alphanumeric characters include letters and numbers.
#
# Given a string `s`, return `true` if it is a palindrome, and `false` otherwise.
#
# **Examples**
#
# Input: "A man, a plan, a canal: Panama"
# Output: true
# Explanation: "amanaplanacanalpanama" is a palindrome.
#
# Input: "race a car"
# Output: false
#
# Input: " "
# Output: true
# Explanation: It becomes an empty string after cleaning.
#
# **Constraints**
#
# 1 <= s.length <= 2 * 10^5
# Contains only printable ASCII characters

# %% [markdown]
# ## Approach
#
# 1. Iterate through the string character by character.
# 2. Keep only the alphanumeric characters.
# 3. Convert all kept characters to lowercase.
# 4. Build a cleaned string using these characters.
# 5. Check whether the cleaned string is equal to its reverse.
# 6. If they match, return `true`; otherwise, return `false`.
#
# Time complexity: O(n)
# Space complexity: O(n)

# %%
class Solution(object):
    def isPalindrome(self, s: str) -> bool:
        """
        :type s: str
        :rtype: bool
        """
        clean = ''
        for char in s:
            if char.isalnum():
                clean += char.lower()
        return clean == clean[::-1]

# %% [markdown]
# ## Rubber Duck Explanation
#
# Imagine explaining your thought process to a rubber duck:
#
# We start with a messy string that may contain spaces, commas, punctuation, and uppercase letters. None of those matter when checking whether something is a palindrome. So we walk through the string and keep only characters that are letters or numbers. Every time we keep one, we convert it to lowercase so everything is consistent.
#
# By the end, we have a clean version of the string that contains only the important characters. Now the question becomes simple: does this cleaned string read the same forward and backward? We reverse it and compare the two. If they're identical, it's a palindrome. If not, it isn’t.
